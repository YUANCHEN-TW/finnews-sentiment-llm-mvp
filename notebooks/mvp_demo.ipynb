# %% [markdown]
# # 金融新聞情緒分析 + LLM 報告生成 (MVP) - Notebook Demo
# 這個 Notebook 幫你快速跑 MVP：資料庫建置 → 模型訓練 → 情緒預測 → 報告生成。
# 建議逐格執行，熟悉 pipeline。

# %% [markdown]
# ## 0. 環境初始化

# %%
# !python -m pip install -U pip
# !pip install -r ../requirements.txt
# !python -m nltk.downloader punkt
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1
#     Uninstalling pip-25.1:
#       Successfully uninstalled pip-25.1
# ...
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      -- ------------------------------------- 1.3/19.2 MB 8.4 MB/s eta 0:00:03
#      ------- -------------------------------- 3.7/19.2 MB 10.4 MB/s eta 0:00:02
#      ------------ --------------------------- 6.0/19.2 MB 10.5 MB/s eta 0:00:02
#      ----------------- ---------------------- 8.4/19.2 MB 10.8 MB/s eta 0:00:01
#      ---------------------- ---------------- 11.0/19.2 MB 11.1 MB/s eta 0:00:01
#      --------------------------- ----------- 13.4/19.2 MB 11.2 MB/s eta 0:00:01
# ...

# %% [markdown]
# ## 1. 建立 SQLite 資料庫與範例新聞

# %%
# %run ../src/etl/demo_seed.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File F:\jupyter\finnews-sentiment-llm-mvp\src\etl\demo_seed.py:5
#       3 from sqlalchemy.orm import declarative_base, sessionmaker
#       4 from datetime import datetime, timedelta
# ----> 5 from src.config import DB_URL
#       6 from src.etl.clean import basic_clean
#       8 Base = declarative_base()
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# ## 2. 訓練 TF-IDF + Logistic Regression baseline

# %%
# %run ../src/models/train_baseline.py

# %% [markdown]
# ## 3. 單句情緒預測

# %%
from src.app.services.scorer import score
text = "台積電法說會釋出利多 訂單上修"
label, prob = score(text)
print(f"Input: {text}\nLabel: {label}, prob={prob:.2f}")

# %% [markdown]
# ## 4. 快速生成每日報告 HTML

# %%
from src.app.services.reporter import generate_daily_report
html = generate_daily_report()
from IPython.display import display, HTML
display(HTML(html))

# %% [markdown]
# ## 5. 啟動 API 與 Dashboard (手動)
# Notebook 只跑後端邏輯，前端建議開兩個終端：
# ```
# uvicorn src.app.main:app --reload  # API Swagger http://127.0.0.1:8000/docs
# streamlit run src/dashboard/app.py # Dashboard http://127.0.0.1:8501
# ```
